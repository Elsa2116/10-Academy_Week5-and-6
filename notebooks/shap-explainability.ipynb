# %% [markdown]
# # SHAP Explainability Review
#
# Task 3 notebook for reviewing generated SHAP plots and drafting business recommendations after running `scripts/run_shap.py`.

# %%
from pathlib import Path
import sys
from IPython.display import Image, display

PROJECT_ROOT = Path.cwd().resolve().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from src.config import FIGURES_DIR

# %%
shap_files = sorted(FIGURES_DIR.glob('*shap*')) + sorted(FIGURES_DIR.glob('*importance*'))
[(path.name, path.stat().st_size) for path in shap_files]

# %%
for path in shap_files:
    if path.suffix.lower() in {'.png', '.jpg', '.jpeg'}:
        print(path.name)
        display(Image(filename=str(path)))

# %% [markdown]
# Recommendation template:
#
# - Driver: name the feature and direction shown by SHAP.
# - Operational action: describe the review, step-up verification, rule, or monitoring change.
# - Business tradeoff: explain expected impact on fraud loss and false-positive risk.
